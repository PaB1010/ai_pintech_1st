# %%
# a태그의 link만 가져와보기

# %%
import requests

url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%B8%94%EB%A1%9C%EA%B7%B8'

response = requests.get(url)

html_text = response.text

print(html_text)

# %%
import re

# 내 풀이 - Group화를 안했다~
pattern = r"<a href=['\"]http[s]?([^'\"]*)['\"][^>]*>"

# 강사님 풀이
pattern = r"<a.*href=['\"]([^'\"]+)['\"][^>]*>"

p = re.compile(pattern, re.I)

# %%
for m in p.finditer(html_text) : 
    print(m.group(1))
# Out:
# https://help.naver.com/support/alias/search/integration/intergration_84.naver
# javascript:void(0);
# //saedu.naver.com/adbiz/searchad/clickChoice.naver
# https://help.naver.com/service/5626/contents/1419
# https://adcr.naver.com/adcr?x=JjNSOxizYpaoWE5MbWi/AP///w==...
# https://adcr.naver.com/adcr?x=JjNSOxizYpaoWE5MbWi/AP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=JjNSOxizYpaoWE5MbWi/AP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=JjNSOxizYpaoWE5MbWi/AP///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=JjNSOxizYpaoWE5MbWi/AP///w==...
# https://adcr.naver.com/adcr?x=F0OYun2qTLu1u1hyZdQ1Ff///w==...
# https://adcr.naver.com/adcr?x=CxaumsJNXH6dn7C7woa6K////w==...
# https://adcr.naver.com/adcr?x=r1QjWcFx2544pgp3vM8ioP///w==...
# https://adcr.naver.com/adcr?x=6IyVeDdN05pBDKjdeIa/2f///w==...
# https://adcr.naver.com/adcr?x=mG4Y/ORb3JNG9h+hmkpTDP///w==...
# https://adcr.naver.com/adcr?x=mG4Y/ORb3JNG9h+hmkpTDP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=mG4Y/ORb3JNG9h+hmkpTDP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=mG4Y/ORb3JNG9h+hmkpTDP///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=mG4Y/ORb3JNG9h+hmkpTDP///w==...
# https://adcr.naver.com/adcr?x=j+YrVUd3WF9Fk8b1eanm0P///w==...
# https://m.pay.naver.com/mobile/about
# https://adcr.naver.com/adcr?x=j+YrVUd3WF9Fk8b1eanm0P///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=j+YrVUd3WF9Fk8b1eanm0P///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=j+YrVUd3WF9Fk8b1eanm0P///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=j+YrVUd3WF9Fk8b1eanm0P///w==...
# https://adcr.naver.com/adcr?x=BzLGCOUazRc9zi56PbJtV////w==...
# https://adcr.naver.com/adcr?x=XOd9i7qBQv0l36J9Jil+Gf///w==...
# https://adcr.naver.com/adcr?x=YyVw2hOKF/E6x1uxJSZpnP///w==...
# https://adcr.naver.com/adcr?x=qDS62ZI72qTTyxcTm0a05////w==...
# https://adcr.naver.com/adcr?x=FUYuONY9taQF4F+DQgJMGf///w==...
# https://adcr.naver.com/adcr?x=FUYuONY9taQF4F+DQgJMGf///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=FUYuONY9taQF4F+DQgJMGf///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=FUYuONY9taQF4F+DQgJMGf///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=FUYuONY9taQF4F+DQgJMGf///w==...
# https://adcr.naver.com/adcr?x=pG1n1duJrkOg8+CyYNCXIv///w==...
# https://adcr.naver.com/adcr?x=XXIZyfdUwTIM+6LlEP6Oif///w==...
# https://adcr.naver.com/adcr?x=Gqe9QeANz9NXcF2x3LQnxP///w==...
# https://adcr.naver.com/adcr?x=FKo3ncTEcIYIj+oQ0UgGPP///w==...
# https://adcr.naver.com/adcr?x=OBVL5cXtPu6TMdRQGppwuf///w==...
# //nid.naver.com/user2/campaign/introNaverIdLogin.nhn
# https://adcr.naver.com/adcr?x=OBVL5cXtPu6TMdRQGppwuf///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=OBVL5cXtPu6TMdRQGppwuf///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=OBVL5cXtPu6TMdRQGppwuf///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=OBVL5cXtPu6TMdRQGppwuf///w==...
# https://adcr.naver.com/adcr?x=uIfcFAcdohfGms+5g/W5Pf///w==...
# https://adcr.naver.com/adcr?x=HoJzVK+BpXxyxX9+yxTEXP///w==...
# https://adcr.naver.com/adcr?x=afkZS4kDeIUM7RcT4VLbxf///w==...
# https://adcr.naver.com/adcr?x=MU3le/vjMJhoEBC2O8qDtv///w==...
# https://adcr.naver.com/adcr?x=MU3le/vjMJhoEBC2O8qDtv///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=MU3le/vjMJhoEBC2O8qDtv///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=MU3le/vjMJhoEBC2O8qDtv///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=MU3le/vjMJhoEBC2O8qDtv///w==...
# https://adcr.naver.com/adcr?x=gzfwZswbiPG6h6LCows3GP///w==...
# //nid.naver.com/user2/campaign/introNaverIdLogin.nhn
# https://adcr.naver.com/adcr?x=gzfwZswbiPG6h6LCows3GP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=gzfwZswbiPG6h6LCows3GP///w==...&amp;p=1
# https://adcr.naver.com/adcr?x=gzfwZswbiPG6h6LCows3GP///w==...&amp;p=0
# https://adcr.naver.com/adcr?x=gzfwZswbiPG6h6LCows3GP///w==...
# javascript:;
# #
# https://blog.naver.com/woodrooster/223057701369
# https://blog.naver.com/woodrooster/223057701369
# #
# https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/
# https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/
# #
# https://sy16.tistory.com/28
# https://sy16.tistory.com/28
# #
# https://blog.naver.com/pakseung98/70118414119
# https://blog.naver.com/pakseung98/70118414119
# #
# https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw
# https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw
# #
# #
# #
# ?nso=&amp;page=2&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web
# https://cafe.naver.com/imsanbu
# https://cafe.naver.com/imsanbu
# https://cafe.naver.com/imsanbu
# http://cafe.naver.com/imsanbu/73317072?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Imltc2FuYnUiLCJhcnRpY2xlSWQiOjczMzE3MDcyLCJpc3N1ZWRBdCI6MTczMjUwMTM1OTcyM30.bX1PAX3e_yHad6J_-mM5yoZZazKEGN7zTbygbJJUUss
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/directwedding
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/makegoodstudy
# https://cafe.naver.com/jpnstory
# https://cafe.naver.com/jpnstory
# https://cafe.naver.com/jpnstory
# ?nso=&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;where=nexearch
# ?nso=&amp;page=2&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web
# ?nso=&amp;page=3&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=16&amp;where=web
# ?nso=&amp;page=4&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=31&amp;where=web
# ?nso=&amp;page=5&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=46&amp;where=web
# ?nso=&amp;page=6&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=61&amp;where=web
# ?nso=&amp;page=7&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=76&amp;where=web
# ?nso=&amp;page=8&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=91&amp;where=web
# ?nso=&amp;page=9&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=106&amp;where=web
# https://ssl.pstatic.net/sstatic/search/pc/css/sp_viewer_241121.css

# %%
# Web Crawling - beautifulsoup

# %%
conda install beautifulsoup4
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# BeautifulSoup에 별칭 bs를 붙임
from bs4 import BeautifulSoup as bs

soup = bs(html_text, 'html.parser')

# %%
items = soup.select('a.news_tit')

for item in items :
    href = item.attrs['href']
    print(href)
# Out:
# https://www.yna.co.kr/view/AKR20241124016000004?input=1195m
# http://www.segye.com/newsView/20241124508913?OutUrl=naver
# https://www.ggilbo.com/news/articleView.html?idxno=1060636
# http://www.domin.co.kr/news/articleView.html?idxno=1492877
